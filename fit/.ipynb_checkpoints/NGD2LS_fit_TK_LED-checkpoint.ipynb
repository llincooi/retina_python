# %% [markdown]
# # Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from matplotlib.ticker import MaxNLocator
import math
from scipy import signal
from scipy.fftpack import fft
from scipy import ndimage
from scipy.io import loadmat
from scipy.optimize import curve_fit
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import import_ipynb
try:
    os.chdir('C:\\Users\\hydro_leo\\Documents\\GitHub\\python-code\\Modules')
except:
    os.chdir('C:\\Users\\llinc\\GitHub\\python-code\\Modules')
from StimulusnResponse import expSnR
# Out:
# importing Jupyter notebook from StimulusnResponse.ipynb

# %%
def NGD2LS_TK(T, alpha, g, l, tau_y, Amp):
    dt = np.mean(np.diff(T))
    dt = 0.1*dt
    T = np.arange(0, T[-1]+dt, dt)
    x = T/tau_y /tau_y *np.exp(-T/tau_y)*dt
    
    y=np.zeros_like(x)
    z=np.zeros_like(x)
    w=np.zeros_like(x)
    #Simplifed Part
    beta = alpha
    gamma = 1./tau_y
    for j in range(len(x)-1):
        dy=dt*(-alpha*y[j] + x[j]-z[j] )
        dz=dt*(-beta*z[j]  + g*y[j] )
        dw=dt*(-gamma*w[j] + y[j]-l*z[j] )
        y[j+1]=y[j]+dy
        z[j+1]=z[j]+dz
        w[j+1]=w[j]+dw

    nTK = w[::10]/(dt) #normalized by integration
    return -Amp*nTK

# %%
#This function deals with differentiation of angle within [-pi,pi).
#It will fail if angle array x change too fast.
def angular_gradient(x):
    diffx= np.gradient(x)
    diffx[np.abs(diffx)>0.6*np.pi] -= np.pi*diffx[np.abs(diffx)>0.6*np.pi]/abs(diffx[np.abs(diffx)>0.6*np.pi])
    return diffx

# %%
figmap = [[np.nan, 7,15,23,31,39,47,np.nan],
          [     1, 8,16,24,32,40,48,    55],
          [     2, 9,17,25,33,41,49,    56],
          [     3,10,18,26,34,42,50,    57],
          [     4,11,19,27,35,43,51,    58],
          [     5,12,20,28,36,44,52,    59],
          [     6,13,21,29,37,45,53,    60],
          [np.nan,14,22,30,38,46,54,np.nan]]
figmap = np.array(figmap)
XOsave = True

# %%
# for exp_date in ['20210506', '20210504', '20210420', '20210413', '20210331']:
for exp_date in ['20200408',  ]:
# for exp_date in ['20210504']:
    exp_folder = 'D:\\GoogleDrive\\retina\\Chou\'s data\\'+exp_date
    filenames = ['D:\\GoogleDrive\\retina\\Chou\'s data\\'+exp_date+'\\'+exp_date+'_cSTA_sort_unit2']
    dt = 0.01
    x_list, T_list, rstate_list = expSnR(filenames, dt, 'LED', np.arange(60)+1)
    x = x_list[0]
    x = x-np.mean(x)
    cSTA_list = [0]*60
    dcn = []
    fig, ax = plt.subplots(nrows=8, ncols=8)
    fig.set_size_inches(60, 30)
    for cn in range(60):
        rstate = rstate_list[0][cn,:]
        if sum(rstate) == 0: continue
        cSTA = np.correlate(x , rstate, 'same')/ np.correlate(np.ones_like(x), rstate, 'same')
        cSTA = cSTA[int(len(cSTA)/2):int(len(cSTA)/2-1/dt)-1:-1]
        taxis = -np.arange(len(cSTA))*dt
        if (np.abs(cSTA[:round(len(cSTA)/2)]) < 7*np.std(cSTA[round(len(cSTA)/2):-1])).all(): continue
        if sum(cSTA[:8]) < -1: dcn.append(cn) # exclude fitting of On-cell
        ax[np.where(figmap == cn+1)][0].plot(taxis, cSTA, 'b+:')
        cSTA_list[cn] = cSTA

    name_list = ['alpha', 'g', 'l', 'tau_y', 'Amp']
    para_dict = {}
    for l in range(len(name_list)):
        para_dict[name_list[l]] = np.zeros(60)
    #-------------------------------------
    fit_cSTA_list = [0]*60
    para_dict['error'] = np.zeros(60)
    for cn in dcn.copy():
    #     print(cn)
        alpha = 10. #1/sec
        g = 680
        l = 0.01
        tau_y = 0.02
        try:
            popt,pcov = curve_fit(NGD2LS_TK, np.abs(taxis), cSTA_list[cn], p0=[alpha, g, l, tau_y, 100],
                                  bounds = (0, [np.inf, np.inf, np.inf, 0.05, np.inf]))
        except:
            dcn.remove(cn)
            continue
        for l in range(len(popt)):
            para_dict[name_list[l]][cn] = popt[l]
    #     print(popt)
        fit_cSTA_list[cn] = NGD2LS_TK(np.abs(taxis), *popt).copy()
        para_dict['error'][cn] = sum((fit_cSTA_list[cn]-cSTA_list[cn])**2)
        ax[np.where(figmap == cn+1)][0].plot(taxis, fit_cSTA_list[cn], 'r-')

    for cn in range(60):
        ax[np.where(figmap == cn+1)][0].set_title(str(cn+1), fontsize = 16)
    fig.set_size_inches(30, 15)
    fig.tight_layout()
    #-------------------------------------
    Dfig, Dax = plt.subplots(nrows=8, ncols=8)
    Dfig.set_size_inches(30, 15)
    Dfig.tight_layout()
    pcn = []
    ncn = []
    for cn in dcn:
        #constrani 1
        if sum(rstate_list[0][cn])/180 < 0.3: continue
        domega = 0.01
        omega = np.arange(-1,10,domega) #limited by [pi/dt,pi/dt)
        TKdw = np.sum(fit_cSTA_list[cn][np.newaxis,:]*np.exp(-1j*np.abs(taxis[np.newaxis,:])*omega[:,np.newaxis]), axis = 1)*dt
        phi = np.angle(TKdw)
        delta = -angular_gradient(phi)/domega
        Dax[np.where(figmap == cn+1)][0].set_title(str(cn+1), fontsize = 16)

        #constrani 2
        if delta[0] < 0: 
            pcn.append(cn)
            Dax[np.where(figmap == cn+1)][0].plot(omega[:-1], delta[:-1], 'g')
        else: 
            ncn.append(cn)
            Dax[np.where(figmap == cn+1)][0].plot(omega[:-1], delta[:-1], 'm')

    for Daxy in Dax:
        for ax in Daxy:
            ax.axhline(0,linewidth=1, linestyle='--', c='k')
            ax.set_xlim([0,10])
    #-------------------------------------
    if XOsave:
        Dfig.set_size_inches(50, 25)
        Dfig.tight_layout()
        Dfig.savefig(exp_folder+'\\TKfit\\NGD2L_GroupDelay.tiff', bbox_inches = 'tight',pad_inches = 0.3)
        np.savez(exp_folder+'\\TKfit\\fitNGD2Lpara.npz', para_dict=para_dict, pcn=pcn, ncn=ncn)
        fig.set_size_inches(50, 25)
        fig.tight_layout()
        fig.savefig(exp_folder+'\TKfit\\fitNGD2Lparameter.tiff', bbox_inches = 'tight',pad_inches = 0.3)

# %%
for v in para_dict.values():
    print(np.mean(v))
# Out:
# 9.337493248840612
# 661.7946487589928
# 0.005404750469450314
# 0.007890359527985448
# 188.2155994168036
# 0.23261282229080932

# %%
import pandas as pd
pd.DataFrame(para_dict)
# Out:
#         alpha            g             l     tau_y          Amp     error
# 0   30.705321  2724.234349  1.201687e-02  0.036689   691.885743  0.422707
# 1    0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 2    0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 3    0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 4    0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 5    0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 6   18.732396   687.162015  2.699322e-02  0.009851   396.800900  0.568522
# 7    0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 8    0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 9    0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 10   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 11   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 12   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 13  14.209668   751.449827  1.874952e-02  0.011976   241.506390  0.292877
# 14  23.270505  3376.109671  5.504700e-03  0.050000   830.235013  1.827504
# 15  32.157903  2567.964844  1.134024e-02  0.035304   960.847502  0.437582
# 16   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 17  52.812875  1538.433309  2.989389e-02  0.025474  1095.275856  0.908763
# 18   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 19   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 20  33.831283  3111.683700  4.539664e-23  0.016602   289.601216  0.385755
# 21   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 22  30.855633  1253.285571  1.931678e-02  0.019529   428.965574  0.369491
# 23   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 24   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 25   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 26   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 27  11.700375   899.227475  7.462122e-03  0.009124   307.388236  0.751516
# 28   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 29  15.587392   937.519996  1.407213e-02  0.010023   344.688461  0.543811
# 30   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 31  28.281928  1156.325065  2.095011e-02  0.016493   294.734210  0.238049
# 32   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 33   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 34   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 35   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 36   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 37  27.604805  2796.654971  6.687284e-03  0.024340   561.276615  0.698417
# 38  14.933356   609.770521  1.984950e-02  0.011856   178.488542  0.171708
# 39  21.642565   820.116999  2.071439e-02  0.014071   247.036988  0.143755
# 40  14.814382   923.517473  1.633620e-02  0.010494   309.735915  0.571902
# 41   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 42   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 43  12.423375  1692.730825  1.846791e-16  0.007291   109.085761  0.668396
# 44  12.390504  1118.929061  7.756240e-03  0.009780   248.408301  0.540974
# 45   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 46  16.206097   773.516165  1.674110e-02  0.010726   296.793244  0.400956
# 47  19.374485   890.037475  1.357982e-02  0.010448   349.966222  0.741667
# 48  19.486406  4104.033136  4.072148e-03  0.050000  1419.221491  1.465598
# 49  25.602419  1060.915425  1.662195e-02  0.015350   321.846000  0.355209
# 50   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 51  15.714721  1178.833718  4.113498e-03  0.010472   224.731368  0.332307
# 52  29.581763  2642.580355  1.009837e-02  0.032136   540.495716  0.244415
# 53   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 54   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 55  24.881878  1071.835589  1.544884e-02  0.015911   323.656424  0.337315
# 56   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 57   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000
# 58  13.447558  1020.811390  5.966108e-03  0.009483   280.264276  0.537575
# 59   0.000000     0.000000  0.000000e+00  0.000000     0.000000  0.000000

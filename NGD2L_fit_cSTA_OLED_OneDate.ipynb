# %% [markdown]
# # HEAD

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from scipy.optimize import curve_fit
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
loadfiles = np.load('D:\\GoogleDrive\\retina\\Chou\'s data\\20210506\\Analyzed_data\\fitNGD2Lpara.npz', allow_pickle=True)
for k in loadfiles.files:
    vars()[k] = loadfiles[k][()]

# %%
data = para_dict['beta'][pcn]
plt.title(r'$\beta"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['alpha'][pcn]
plt.title(r'$\alpha"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['gamma'][pcn]
plt.title(r'$\gamma"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['g'][pcn]
plt.title(r'$g$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['h'][pcn]
plt.title(r'$h$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['l'][pcn]
plt.title(r'$l"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['Amp'][pcn]
plt.title(r'$Amp$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
# I1 = np.where((para_dict['beta']>10) & (para_dict['beta']<40) )[0]
# I2 = np.where((para_dict['beta']<=10) & (para_dict['beta']>0))[0]

# %%
plt.scatter(para_dict['alpha'][pcn], para_dict['beta'][pcn], c ='b')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\beta$')
# Out:
# Text(0, 0.5, '$\\beta$')

# %%
plt.scatter(para_dict['h'][pcn], para_dict['l'][pcn], c ='b')
plt.xlabel(r'$h$')
plt.ylabel(r'$l$')
# Out:
# Text(0, 0.5, '$l$')

# %%
plt.scatter(para_dict['alpha'][pcn], para_dict['g'][pcn], c ='b')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$g$')
# Out:
# Text(0, 0.5, '$g$')

# %% [markdown]
# # filter by ...

# %%
Index = np.where(np.abs(para_dict['alpha']/para_dict['beta']-1)<0.1)
Index = np.intersect1d(pcn,Index)
Index
# Out:
# array([ 1,  2,  4,  5, 10, 11, 12, 13, 14, 18, 23, 24, 29, 32, 39, 40, 49],
#       dtype=int64)

# %%
data = para_dict['beta'][pcn]
plt.title(r'$\beta"$')
plt.hist(data,30)
data = para_dict['beta'][Index]
plt.title(r'$\beta"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['alpha'][pcn]
plt.title(r'$\alpha"$')
plt.hist(data,30)
data = para_dict['alpha'][Index]
plt.title(r'$\alpha"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['gamma'][pcn]
plt.title(r'$\gamma"$')
plt.hist(data,30)
data = para_dict['gamma'][Index]
plt.title(r'$\gamma"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['g'][pcn]
plt.title(r'$g$')
plt.hist(data,30)
data = para_dict['g'][Index]
plt.title(r'$g$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['h'][pcn]
plt.title(r'$h$')
plt.hist(data,30)
data = para_dict['h'][Index]
plt.title(r'$h$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['l'][pcn]
plt.title(r'$l"$')
plt.hist(data,30)
data = para_dict['l'][Index]
plt.title(r'$l"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['Amp'][pcn]
plt.title(r'$Amp$')
plt.hist(data,30)
data = para_dict['Amp'][Index]
plt.title(r'$Amp$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
# I1 = np.where((para_dict['beta']>10) & (para_dict['beta']<40) )[0]
# I2 = np.where((para_dict['beta']<=10) & (para_dict['beta']>0))[0][Index]

# %%
plt.scatter(para_dict['alpha'][pcn], para_dict['beta'][pcn], c ='b')
plt.scatter(para_dict['alpha'][Index], para_dict['beta'][Index], c ='r')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\beta$')
# Out:
# Text(0, 0.5, '$\\beta$')

# %%
plt.scatter(para_dict['h'][pcn], para_dict['l'][pcn], c ='b')
plt.scatter(para_dict['h'][Index], para_dict['l'][Index], c ='r')
plt.xlabel(r'$h$')
plt.ylabel(r'$l$')
# Out:
# Text(0, 0.5, '$l$')

# %%
plt.scatter(para_dict['alpha'][pcn], para_dict['g'][pcn], c ='b')
plt.scatter(para_dict['alpha'][Index], para_dict['g'][Index], c ='r')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$g$')
# Out:
# Text(0, 0.5, '$g$')

# %%
data = para_dict['beta'][pcn]/para_dict['alpha'][pcn]
plt.title(r'$\frac{\beta}{\alpha}$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['h'][pcn]/para_dict['l'][pcn]
plt.title(r'$\frac{h}{l}$')
plt.hist(data,30)
data = para_dict['h'][Index]/para_dict['l'][Index]
plt.title(r'$\frac{h}{l}$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %% [markdown]
# # Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from scipy.optimize import curve_fit
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import import_ipynb
try:
    os.chdir('C:\\Users\\hydro_leo\\Documents\\GitHub\\python-code\\Modules')
except:
    os.chdir('C:\\Users\\llinc\\GitHub\\python-code\\Modules')
from StimulusnResponse import expSnR
# Out:
# importing Jupyter notebook from StimulusnResponse.ipynb

# %%
def NGD2L_TK(T, alpha, beta, gamma, g, h, l, tau_y, Amp):
    dt = np.mean(np.diff(T))
    dt = 0.1*dt
    T = np.arange(0, T[-1]+dt, dt)
    x = T/tau_y /tau_y *np.exp(-T/tau_y)*dt
    
    y=np.zeros_like(x)
    z=np.zeros_like(x)
    w=np.zeros_like(x)
    for j in range(len(x)-1):
        dy=dt*(-alpha*y[j] + x[j]-z[j] )
        dz=dt*(-beta*z[j]  + g*y[j] )
        dw=dt*(-gamma*w[j] + h*y[j]-l*z[j] )
        y[j+1]=y[j]+dy
        z[j+1]=z[j]+dz
        w[j+1]=w[j]+dw

    nTK = w[::10]/(dt) #normalized by integration
    return -Amp*nTK

# %%
#This function deals with differentiation of angle within [-pi,pi).
#It will fail if angle array x change too fast.
def angular_gradient(x):
    diffx= np.gradient(x)
    diffx[np.abs(diffx)>0.6*np.pi] -= np.pi*diffx[np.abs(diffx)>0.6*np.pi]/abs(diffx[np.abs(diffx)>0.6*np.pi])
    return diffx

# %%
figmap = [[np.nan, 7,15,23,31,39,47,np.nan],
          [     1, 8,16,24,32,40,48,    55],
          [     2, 9,17,25,33,41,49,    56],
          [     3,10,18,26,34,42,50,    57],
          [     4,11,19,27,35,43,51,    58],
          [     5,12,20,28,36,44,52,    59],
          [     6,13,21,29,37,45,53,    60],
          [np.nan,14,22,30,38,46,54,np.nan]]
figmap = np.array(figmap)
XOsave = True

# %%
for exp_date in ['20200408']:
# for exp_date in ['20210504']:
    exp_folder = 'D:\\GoogleDrive\\retina\\Chou\'s data\\'+exp_date
    filenames = ['D:\\GoogleDrive\\retina\\Chou\'s data\\'+exp_date+'\\'+exp_date+'_cSTA_sort_unit2']
    dt = 0.01
    x_list, T_list, rstate_list = expSnR(filenames, dt, 'LED', np.arange(60)+1)
    x = x_list[0]
    x = x-np.mean(x)
    cSTA_list = [0]*60
    dcn = []
    fig, ax = plt.subplots(nrows=8, ncols=8)
    fig.set_size_inches(60, 30)
    for cn in range(60):
        rstate = rstate_list[0][cn,:]
        if sum(rstate) == 0: continue
        cSTA = np.correlate(x , rstate, 'same')/ np.correlate(np.ones_like(x), rstate, 'same')
        cSTA = cSTA[int(len(cSTA)/2):int(len(cSTA)/2-1/dt)-1:-1]
        taxis = -np.arange(len(cSTA))*dt
        if (np.abs(cSTA[:round(len(cSTA)/2)]) < 7*np.std(cSTA[round(len(cSTA)/2):-1])).all(): continue
        if sum(cSTA[:8]) < -1: dcn.append(cn) # exclude fitting of On-cell
        ax[np.where(figmap == cn+1)][0].plot(taxis, cSTA, 'b+:')
        cSTA_list[cn] = cSTA

    name_list = ['alpha', 'beta', 'gamma', 'g', 'h', 'l', 'tau_y', 'Amp']
    para_dict = {}
    for l in range(len(name_list)):
        para_dict[name_list[l]] = np.zeros(60)
    #-------------------------------------
    fit_cSTA_list = [0]*60
    para_dict['error'] = np.zeros(60)
    for cn in dcn.copy():
    #     print(cn)
        alpha = 10. #1/sec
        beta =  10.
        gamma = 42.
        g = 680
        h = 80
        i = 0.8
        tau_y = 0.07
        try:
            popt,pcov = curve_fit(NGD2L_TK, np.abs(taxis), cSTA_list[cn], p0=[alpha, beta, gamma, g, h, i, tau_y, 1],
                                  bounds = (0, [np.inf, np.inf, np.inf, np.inf, np.inf, np.inf, 0.05, np.inf]))
        except:
            dcn.remove(cn)
            continue
        for l in range(len(popt)):
            para_dict[name_list[l]][cn] = popt[l]
    #     print(popt)
        fit_cSTA_list[cn] = NGD2L_TK(np.abs(taxis), *popt).copy()
        para_dict['error'][cn] = sum((fit_cSTA_list[cn]-cSTA_list[cn])**2)
        ax[np.where(figmap == cn+1)][0].plot(taxis, fit_cSTA_list[cn], 'r-')
    
    for cn in range(60):
        ax[np.where(figmap == cn+1)][0].set_title(str(cn+1), fontsize = 16)
    fig.set_size_inches(30, 15)
    fig.tight_layout()
    #-------------------------------------
    Dfig, Dax = plt.subplots(nrows=8, ncols=8)
    Dfig.set_size_inches(30, 15)
    Dfig.tight_layout()
    pcn = []
    ncn = []
    for cn in dcn:
        #constrani 1
        if sum(rstate_list[0][cn])/180 < 0.3: continue
        domega = 0.01
        omega = np.arange(-1,10,domega) #limited by [pi/dt,pi/dt)
        TKdw = np.sum(fit_cSTA_list[cn][np.newaxis,:]*np.exp(-1j*np.abs(taxis[np.newaxis,:])*omega[:,np.newaxis]), axis = 1)*dt
        phi = np.angle(TKdw)
        delta = -angular_gradient(phi)/domega
        Dax[np.where(figmap == cn+1)][0].set_title(str(cn+1), fontsize = 16)

        #constrani 2
        if delta[0] < 0: 
            pcn.append(cn)
            Dax[np.where(figmap == cn+1)][0].plot(omega[:-1], delta[:-1], 'g')
        else: 
            ncn.append(cn)
            Dax[np.where(figmap == cn+1)][0].plot(omega[:-1], delta[:-1], 'm')

    for Daxy in Dax:
        for ax in Daxy:
            ax.axhline(0,linewidth=1, linestyle='--', c='k')
            ax.set_xlim([0,10])
    #-------------------------------------
    if XOsave:
        Dfig.set_size_inches(50, 25)
        Dfig.tight_layout()
        Dfig.savefig(exp_folder+'\\TKfit\\NGD2L_GroupDelay.tiff', bbox_inches = 'tight',pad_inches = 0.3)
        np.savez(exp_folder+'\\TKfit\\fitNGD2Lpara.npz', para_dict=para_dict, pcn=pcn, ncn=ncn)
        fig.set_size_inches(50, 25)
        fig.tight_layout()
        fig.savefig(exp_folder+'\TKfit\\fitNGD2Lparameter.tiff', bbox_inches = 'tight',pad_inches = 0.3)

# %%
for v in para_dict.values():
    print(np.mean(v))
# Out:
# 8.80026854001153
# 5.599652878997737
# 383.87056358744127
# 458.86135257422234
# 54.440398931451014
# 0.5776218135048653
# 0.006888345422699294
# 12.912340183048482
# 0.15103062638233786

# %%
plt.scatter(para_dict['alpha'], para_dict['beta'], c ='b')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\beta$')
# Out:
# Text(0, 0.5, '$\\beta$')

# %%
plt.scatter(para_dict['tau_y'], para_dict['gamma'], c ='b')
plt.xlabel(r'$\tau_y$')
plt.ylabel(r'$\gamma$')
# Out:
# Text(0, 0.5, '$\\gamma$')

# %%
import pandas as pd
pd.DataFrame(para_dict)
# Out:
#         alpha       beta        gamma            g           h         l  \
# 0   61.781110  11.637576    48.466401   490.339756   53.400933  1.434802
# 1    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 2    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 3    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 4    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 5    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 6   23.469086  22.201979  1952.326926   971.930996  178.178271  4.043809
# 7    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 8    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 9    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 10   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 11   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 12   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 13  23.301035   6.581994  1867.422192   957.889839  366.799424  2.432312
# 14  22.237874  21.508815     3.475945  2905.990780   65.081003  0.474242
# 15   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 16   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 17   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 18   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 19  62.636168   6.083897    48.781591   591.596587  147.276938  1.128382
# 20   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 21   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 22  23.741002  14.261426  2003.170436  1921.789151  291.653493  1.506296
# 23   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 24   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 25   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 26   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 27  17.518765   7.126286  1873.689337   986.933486  268.536686  0.590990
# 28   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 29  21.045545  12.378175  1893.001549  1121.119261  153.925787  1.366908
# 30   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 31   9.266368  22.156467     7.597227  1517.951861   68.223713  0.965524
# 32   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 33  67.323858  12.294200    65.146549   116.288194   99.132449  5.803884
# 34   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 35   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 36   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 37   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 38  12.553797  12.097921    12.580948   912.762698  122.644331  1.452364
# 39  23.799541  17.269803  1844.594384  1308.881312  141.239142  1.435853
# 40  21.259859   9.753362  1876.690186  1101.575059  223.532900  1.961610
# 41  18.189446  31.435525  1943.767191  1728.067066  120.221921  1.985354
# 42   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 43   8.936832  15.175409  1751.393499  1743.417796   86.782221  0.015823
# 44  12.386540  12.393104    98.829833  1118.772972   95.039234  0.737519
# 45   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 46  17.773810  19.103265  1934.926418   993.514570  160.001916  2.618212
# 47   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
#
# %% [markdown]
# # Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import logging
logging.getLogger().setLevel(logging.CRITICAL)

# %%
def ensure_dir(file_path):
    if not os.path.exists(file_path):
        os.makedirs(file_path)

# %% [markdown]
# # Main

# %%
figmap = [[np.nan, 7,15,23,31,39,47,np.nan],
          [     1, 8,16,24,32,40,48,    55],
          [     2, 9,17,25,33,41,49,    56],
          [     3,10,18,26,34,42,50,    57],
          [     4,11,19,27,35,43,51,    58],
          [     5,12,20,28,36,44,52,    59],
          [     6,13,21,29,37,45,53,    60],
          [np.nan,14,22,30,38,46,54,np.nan]]
figmap = np.array(figmap)

# %%
exp_folder = 'D:\\GoogleDrive\\retina\\Exps\\2021\\1212\\'
# exp_folder = 'D:\\GoogleDrive\\retina\\Troy\'s data\\20211209\\'
direction = 'UR_DL'
ensure_dir(exp_folder+'MI')
ensure_dir(exp_folder+'MI\\Fig')
ensure_dir(exp_folder+'MI\\Fig\\perSpike')

# %%
MIdFcfig, MIdFcax = plt.subplots(nrows=8, ncols=8)
cmind = 0
for Mean in [4,7,10,13,19,31,49]:
    try:
        loadfiles = np.load(exp_folder+'MI\\MIperSpike_merge_1211_WF_LPOU_G4.5_1Hz__'+str(Mean)+'-0.1mW.npz', allow_pickle=True)
    except:
        cmind += 1
        continue
    for k in loadfiles.files:
        vars()[k] = loadfiles[k][()]

    for cn in range(60):
        Information = Information_cell[cn]
        try:
            MIdFcax[np.where(figmap == cn+1)][0].plot(timeshift,Information, label=str(Mean), color = plt.cm.tab10(cmind))
            MIdFcax[np.where(figmap == cn+1)][0].set_title(str(cn+1), fontsize = 20)
        except:
            continue
#         MIdFcax[np.where(figmap == cn+1)][0].set_xlabel(r'$\delta t$ (s)', fontsize = 16)
#         MIdFcax[np.where(figmap == cn+1)][0].set_ylabel(r'Information (bit/s)', fontsize = 16)
    cmind += 1

for ax1d in MIdFcax:
    for ax in ax1d:
        ax.legend(fontsize = 12)
        ax.grid()
MIdFcfig.set_size_inches(60, 30)
MIdFcfig.tight_layout()
MIdFcfig.savefig(exp_folder+'MI\\Fig\\perSpike\\dMCC=0.1_1Hz.tif', bbox_inches = 'tight',pad_inches = 0.3)

# %%
# filenames = ['merge_1207_LPOU_G4.5_1Hz_SW_hw8_long_'+direction+'_6.5v3.25mW',
#              'merge_1207_LPOU_G4.5_1Hz_SW_hw8_long_'+direction+'_13v6.5mW',
#              'merge_1207_LPOU_G4.5_1Hz_SW_hw8_long_'+direction+'_26v13mW',
#              'merge_1208_LPOU_G4.5_1Hz_SW_hw8_long_'+direction+'_65v32.5mW',]
# Mag_list = [1,2,4,10]

# MIdFcfig, MIdFcax = plt.subplots(nrows=8, ncols=8)
# cmind = 0
# for filename in filenames:
#     try:
#         loadfiles = np.load(exp_folder+'MI\\MIperSpike_'+filename+'.npz', allow_pickle=True)
#     except:
#         cmind += 1
#         continue
#     for k in loadfiles.files:
#         vars()[k] = loadfiles[k][()]

#     for cn in range(60):
#         Information = Information_cell[cn]
#         try:
#             MIdFcax[np.where(figmap == cn+1)][0].plot(timeshift,Information, label='Mag='+str(Mag_list[cmind]), color = plt.cm.tab10(cmind))
#             MIdFcax[np.where(figmap == cn+1)][0].set_title(str(cn+1), fontsize = 20)
#         except:
#             continue
# #         MIdFcax[np.where(figmap == cn+1)][0].set_xlabel(r'$\delta t$ (s)', fontsize = 16)
# #         MIdFcax[np.where(figmap == cn+1)][0].set_ylabel(r'Information (bit/s)', fontsize = 16)
#     cmind += 1

# for ax1d in MIdFcax:
#     for ax in ax1d:
#         ax.legend(fontsize = 12)
#         ax.grid()
# MIdFcfig.set_size_inches(60, 30)
# MIdFcfig.tight_layout()
# MIdFcfig.savefig(exp_folder+'MI\\Fig\\perSpike\\dMag_6.5v3.25_1Hz.tif', bbox_inches = 'tight',pad_inches = 0.3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import signal
from scipy.fftpack import fft
from scipy import ndimage
from scipy.io import loadmat
annots = loadmat('C:\\Users\\llinc\\GitHub\\retina_personal\\0406\\merge\\merge_0224_OUsmooth_RL_G4.5_5min_Q100_6.5mW_1Hz.mat')

# %%
annots
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Sat Apr 11 14:25:42 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'TimeStamps': array([[ 19.11265, 319.2022 ]]),
#  'BinningInterval': array([[0.01666609]]),
#  'diode_BT': array([[1.66660891e-02, 3.33321782e-02, 4.99982672e-02, ...,
#          3.00056268e+02, 3.00072934e+02, 3.00089600e+02]]),
#  'bin_pos': array([[406, 406, 406, ..., 416, 416, 417]], dtype=uint16),
#  'reconstruct_spikes': array([[array([[1.1240000e-01, 1.1770000e-01, 1.1785000e-01, 1.2550000e-01,
#          1.2895000e-01, 1.3635000e-01, 1.4010000e-01, 1.4240000e-01,
#          1.4915000e-01, 1.5510000e-01, 1.5525000e-01, 1.6580000e-01,
#          1.7215000e-01, 1.8215000e-01, 1.8230000e-01, 1.9640000e-01,
#          2.7545000e-01, 2.7560000e-01, 1.4416500e+00, 6.2499500e+00,
#          1.0595850e+01, 2.0721350e+01, 2.2423650e+01, 2.8523550e+01,
#          3.1267500e+01, 3.1954750e+01, 3.2097650e+01, 3.9888350e+01,
# ...

# %%
annots['bin_pos']
# Out:
# array([[406, 406, 406, ..., 416, 416, 417]], dtype=uint16)

# %%
np.shape(annots['diode_BT'])
# Out:
# (1, 18006)

# %%
annots['reconstruct_spikes'][0][59]
# Out:
# array([[8.1600000e-02, 1.3710000e-01, 1.4120000e-01, ..., 2.9975180e+02,
#         2.9975395e+02, 2.9984370e+02]])

# %%
import os
os.chdir("C:\\Users\\llinc\\GitHub\\retina_personal\\0406\\merge")
os.getcwd()
# Out:
# 'C:\\Users\\llinc\\GitHub\\retina_personal\\0406\\merge'

# %%
annots['diode_BT']
# Out:
# array([[1.66660891e-02, 3.33321782e-02, 4.99982672e-02, ...,
#         3.00056268e+02, 3.00072934e+02, 3.00089600e+02]])

# %%
from Pin import Pin
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-0b8d6c63b99b> in <module>
# ----> 1 from Pin import Pin
#
# ModuleNotFoundError: No module named 'Pin'

# %%
Pin(3)

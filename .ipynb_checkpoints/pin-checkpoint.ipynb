# %%
from scipy.io import loadmat
annots = loadmat('merge_0224_OUsmooth_RL_G4.5_5min_Q100_6.5mW_1Hz.mat')

# %%
annots
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Mon May  4 22:26:27 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'TimeStamps': array([[ 18.9809 , 319.05385]]),
#  'BinningInterval': array([[0.01666609]]),
#  'diode_BT': array([[1.66660928e-02, 3.33321855e-02, 4.99982783e-02, ...,
#          3.00039668e+02, 3.00056334e+02, 3.00073000e+02]]),
#  'bin_pos': array([[406, 406, 406, ..., 416, 416, 417]], dtype=uint16),
#  'reconstruct_spikes': array([[array([[1.1990000e-01, 2.2395000e-01, 2.3175000e-01, 3.3340000e-01,
#          4.2505000e-01, 6.2435000e-01, 6.7505000e-01, 8.9000000e-01,
#          1.4648500e+00, 1.5837500e+00, 2.1785000e+00, 2.8091000e+00,
#          4.5640500e+00, 4.6175000e+00, 4.6673500e+00, 4.7546000e+00,
#          4.8284000e+00, 5.0570000e+00, 5.3644500e+00, 7.1993000e+00,
#          7.2629500e+00, 7.3389500e+00, 1.1828450e+01, 1.6280800e+01,
#          1.7126650e+01, 1.7424200e+01, 1.7432400e+01, 1.7435100e+01,
# ...

# %%
annots['bin_pos']
# Out:
# array([[406, 406, 406, ..., 416, 416, 417]], dtype=uint16)

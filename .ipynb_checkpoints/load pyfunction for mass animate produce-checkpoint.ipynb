# %%
import os
os.chdir('module for mass production')

# %%
from test_amp import mass_animate_producer

# %%
for cutoffFreq in [0.5,1,2,4,8]:
    for channelnumber in [30,52]:
        mass_animate_producer(cutoffFreq, channelnumber)
# Out:
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\test_amp.py:94: RuntimeWarning: divide by zero encountered in log2
#   MIxr=np.nansum(pxr*np.log2(pxr/px/pr))/dt
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\test_amp.py:94: RuntimeWarning: invalid value encountered in multiply
#   MIxr=np.nansum(pxr*np.log2(pxr/px/pr))/dt
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\test_amp.py:95: RuntimeWarning: divide by zero encountered in log2
#   MIvr=np.nansum(pvr*np.log2(pvr/pv/pr))/dt
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\test_amp.py:95: RuntimeWarning: invalid value encountered in multiply
#   MIvr=np.nansum(pvr*np.log2(pvr/pv/pr))/dt
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\test_amp.py:96: RuntimeWarning: invalid value encountered in true_divide
#   MIxvR=np.nansum(pxvr*np.log2(pxvr/pxv/pr))/dt
# ...

# %%
from WF_amp import mass_animate_producer

# %%
for cutoffFreq in [2,4,7,10]:
    for channelnumber in [36,53]:
        mass_animate_producer(cutoffFreq, channelnumber)
# Out:
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\WF_amp.py:93: RuntimeWarning: divide by zero encountered in log2
#   MIxr=np.nansum(pxr*np.log2(pxr/px/pr))/dt
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\WF_amp.py:93: RuntimeWarning: invalid value encountered in multiply
#   MIxr=np.nansum(pxr*np.log2(pxr/px/pr))/dt
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\WF_amp.py:94: RuntimeWarning: divide by zero encountered in log2
#   MIvr=np.nansum(pvr*np.log2(pvr/pv/pr))/dt
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\WF_amp.py:94: RuntimeWarning: invalid value encountered in multiply
#   MIvr=np.nansum(pvr*np.log2(pvr/pv/pr))/dt
# C:\Users\hydro_leo\Documents\GitHub\python-code\module for mass production\WF_amp.py:95: RuntimeWarning: invalid value encountered in true_divide
#   MIxvR=np.nansum(pxvr*np.log2(pxvr/pxv/pr))/dt
# ...

# %% [markdown]
# # HEAD

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from scipy.optimize import curve_fit
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
loadfiles = np.load('D:\\GoogleDrive\\retina\\Chou\'s data\\20210331\\Analyzed_data\\fitNGD2Lpara.npz', allow_pickle=True)
for k in loadfiles.files:
    vars()[k] = loadfiles[k][()]
for k in para_dict.keys():
    para_dict[k] = para_dict[k][pcn]

for date in ['0413', '0420', '0504','0506']:
    loadfiles = np.load('D:\\GoogleDrive\\retina\\Chou\'s data\\2021'+date+'\\Analyzed_data\\fitNGD2Lpara.npz', allow_pickle=True)
    for k in loadfiles.files:
        vars()['new_'+k] = loadfiles[k][()]
    for k in para_dict.keys():
        para_dict[k] = np.append(para_dict[k], new_para_dict[k][new_pcn])

# %%
data = para_dict['beta']
plt.title(r'$\beta"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['alpha']
plt.title(r'$\alpha"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['gamma']
plt.title(r'$\gamma"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['g']
plt.title(r'$g$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['h']
plt.title(r'$h$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['l']
plt.title(r'$l"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
data = para_dict['tau_y']
plt.title(r'$\tau_y$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 0.027316479072806158

# %%
data = para_dict['Amp']
plt.title(r'$Amp$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
# I1 = np.where((para_dict['beta']>10) & (para_dict['beta']<40) )[0]
# I2 = np.where((para_dict['beta']<=10) & (para_dict['beta']>0))[0]

# %%
plt.scatter(para_dict['alpha'], para_dict['beta'], c ='b')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\beta$')
# Out:
# Text(0, 0.5, '$\\beta$')

# %%
plt.scatter(para_dict['h'], para_dict['l'], c ='b')
plt.xlabel(r'$h$')
plt.ylabel(r'$l$')
# Out:
# Text(0, 0.5, '$l$')

# %%
plt.scatter(para_dict['alpha'], para_dict['g'], c ='b')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$g$')
# Out:
# Text(0, 0.5, '$g$')

# %% [markdown]
# # filter by ...

# %%
Index1 = np.where(np.abs(para_dict['alpha']/para_dict['beta']-1)<0.1)
Index2 = np.where(np.abs(para_dict['tau_y']*para_dict['gamma']-1)<0.1)
Index3 = np.where(para_dict['error']<2)

Index = np.intersect1d(Index1, Index2, Index3)

# %%
data = para_dict['beta']
plt.title(r'$\beta"$')
plt.hist(data,30)
data = para_dict['beta'][Index]
plt.title(r'$\beta"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 13.37478211885722

# %%
data = para_dict['alpha']
plt.title(r'$\alpha"$')
plt.hist(data,30)
data = para_dict['alpha'][Index]
plt.title(r'$\alpha"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 13.387716875068989

# %%
data = para_dict['gamma']
plt.title(r'$\gamma"$')
plt.hist(data,30)
data = para_dict['gamma'][Index]
plt.title(r'$\gamma"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 36.42599541121415

# %%
data = para_dict['g']
plt.title(r'$g$')
plt.hist(data,30)
data = para_dict['g'][Index]
plt.title(r'$g$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 839.4916035423445

# %%
data = para_dict['h']
plt.title(r'$h$')
plt.hist(data,30)
data = para_dict['h'][Index]
plt.title(r'$h$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 149.5689821361509

# %%
data = para_dict['l']
plt.title(r'$l"$')
plt.hist(data,30)
data = para_dict['l'][Index]
plt.title(r'$l"$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 1.8320071318306494

# %%
data = para_dict['tau_y']
plt.title(r'$\tau_y$')
plt.hist(data,30)
data = para_dict['tau_y'][Index]
plt.title(r'$\tau_y$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 0.02741984376370517

# %%
data = para_dict['Amp']
plt.title(r'$Amp$')
plt.hist(data,30)
data = para_dict['Amp'][Index]
plt.title(r'$Amp$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')
np.mean(data)
# Out:
# 3.4685142416948564

# %%
data = para_dict['error']
plt.title(r'$error$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %%
plt.scatter(para_dict['alpha'], para_dict['beta'], c ='b')
plt.scatter(para_dict['alpha'][Index], para_dict['beta'][Index], c ='r')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\beta$')

lims = [0, np.max(np.append(para_dict['alpha'], para_dict['beta']))+1]
plt.plot(lims, lims, 'k-', alpha=0.75, zorder=0)

# %%
plt.scatter(para_dict['tau_y'], para_dict['gamma'], c ='b')
plt.scatter(para_dict['tau_y'][Index], para_dict['gamma'][Index], c ='r')
plt.xlabel(r'$\tau_y$')
plt.ylabel(r'$\gamma$')

taxis = np.linspace(0.005, 0.1, 1000)
plt.plot(taxis, 0.97/taxis, 'k-', alpha=0.75, zorder=0)

# %%
plt.scatter(para_dict['h'], para_dict['l'], c ='b')
plt.scatter(para_dict['h'][Index], para_dict['l'][Index], c ='r')
plt.xlabel(r'$h$')
plt.ylabel(r'$l$')

lims = [0, np.max(para_dict['h'])]
plt.plot(lims, np.array(lims)/50, 'k-', alpha=0.75, zorder=0)
plt.plot(lims, np.array(lims)/100, 'k-', alpha=0.75, zorder=0)
plt.plot(lims, np.array(lims)/200, 'k-', alpha=0.75, zorder=0)

# %%
plt.scatter(para_dict['alpha'], para_dict['g'], c ='b')
plt.scatter(para_dict['alpha'][Index], para_dict['g'][Index], c ='r')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$g$')
# Out:
# Text(0, 0.5, '$g$')

# %%
data = para_dict['beta']/para_dict['alpha']
plt.title(r'$\frac{\beta}{\alpha}$')
plt.hist(data,30)
plt.axvline(np.mean(data[Index]), color = 'r')
np.mean(data[Index])
# Out:
# 0.9991891549312022

# %%
data = para_dict['tau_y']*para_dict['gamma']
plt.title(r'$\tau_y*\gamma$')
plt.hist(data,30)
plt.axvline(np.mean(data[Index]), color = 'r')
np.mean(data[Index])
# Out:
# 0.969196935384079

# %%
data = para_dict['h']/para_dict['l']
plt.title(r'$\frac{h}{l}$')
plt.hist(data,30)
data = para_dict['h'][Index]/para_dict['l'][Index]
plt.title(r'$\frac{h}{l}$')
plt.hist(data,30)
plt.axvline(np.mean(data), color = 'r')

# %% [markdown]
# # plot TK

# %%
def plotNGD2L_TK(T, alpha, beta, gamma, g, h, l, tau_y, Amp):
    dt = np.mean(np.diff(T))
    dt = 0.1*dt
    T = np.arange(0, T[-1]+dt, dt)
    x = T/tau_y /tau_y *np.exp(-T/tau_y)*dt
    
    y=np.zeros_like(x)
    z=np.zeros_like(x)
    w=np.zeros_like(x)
    for j in range(len(x)-1):
        dy=dt*(-alpha*y[j] + x[j]-z[j] )
        dz=dt*(-beta*z[j]  + g*y[j] )
        dw=dt*(-gamma*w[j] + h*y[j]-l*z[j] )
        y[j+1]=y[j]+dy
        z[j+1]=z[j]+dz
        w[j+1]=w[j]+dw

    nTK = w[::10]/(dt) #normalized by integration
    plt.plot(nTK)

# %%
import pandas as pd
data_df = pd.DataFrame(para_dict)
T = np.arange(0,1,0.01)

# %%
data_df
# Out:
#          alpha       beta       gamma            g           h         l  \
# 0    24.161824  25.401913   10.484708  1713.530310  109.693719  1.572936
# 1    14.328995  12.235700  202.331438  1254.552821  176.717750  1.625744
# 2    22.676763  22.331667    9.075367  1535.887365  111.291119  1.506927
# 3    18.606535  17.263745  138.599984  1229.730152  268.368557  2.786785
# 4    33.948476  33.949174   30.296385  1649.633214  136.492566  2.635109
# ..         ...        ...         ...          ...         ...       ...
# 115  12.514069  12.513761   35.691806   812.860284   55.400320  0.648138
# 116  14.089837  14.090158   28.725397  1250.866215   58.544853  0.511802
# 117  11.351587  11.351438   43.296821   632.165445   55.549594  0.621158
# 118   1.294060  14.557487   57.936877   617.575715   55.464239  0.652480
# 119  19.090238  19.090442   23.565508  1076.565306  106.122442  1.569295
#
#         tau_y        Amp     error
# 0    0.022839   4.154213  0.428255
# 1    0.062979  28.494257  2.973695
# 2    0.021966   3.218314  0.592209
# 3    0.045498   7.151103  0.472002
# 4    0.032171   7.416753  0.334638
# ..        ...        ...       ...
# 115  0.027175   5.632688  0.601109
# 116  0.033955   6.950312  0.435365
# 117  0.022252   4.993365  1.092099
# 118  0.016410   4.888065  3.042038
# 119  0.041580   4.946375  1.785859
#
# [120 rows x 9 columns]

# %%
for I in Index:
    plotNGD2L_TK(T, *data_df.loc[I][:-1])

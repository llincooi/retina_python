# %%
import numpy as np
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline

# %%
sigma = 10
klen = sigma*5
x = np.arange(-klen,klen+1)[:,np.newaxis]
y = np.arange(-klen,klen+1)[np.newaxis,:]

k1 = np.exp(-(x**2+y**2+x*y)/sigma**2)

# %%
plt.imshow(k1,cmap='gray')

# %%
plt.plot(k1[:,klen+1]/ max(k1[:,klen+1]))
plt.plot(k1[:,klen+1-sigma]/ max(k1[:,klen+1-sigma]))

# %%
k2part = np.zeros_like(k1)
k2 = np.concatenate((k2part[:-1,:], k1), axis = 0)
plt.imshow(k2,cmap='gray')

# %%
k2.shape, k1.shape
# Out:
# ((201, 101), (101, 101))

# %% [markdown]
# ## signal.convolve2d

# %%
s = np.random.randint(5, size=(1000,1000))-2
s = s.astype(float)

# %%
import time
t0 = time.time()
r = signal.convolve2d(s,k2,'same')
print(time.time()-t0)
# Out:
# 42.99911952018738

# %% [markdown]
# ## Leo's method

# %%
t0 = time.time()
mb_y = np.zeros_like(s)
for i in range(s.shape[0]):
    for ii in np.arange(max(i-np.shape(k1)[0]+1,0),i+1):
        mb_y[i,:] += np.convolve(s[ii,:],k1[i-ii, :], 'same')
print(time.time()-t0)
# Out:
# 3.2509889602661133

# %%
mb_y - r
# Out:
# array([[ 1.61558713e-27, -3.23117427e-27,  0.00000000e+00, ...,
#         -1.65436123e-24,  4.54949337e-24, -1.03397577e-24],
#        [ 0.00000000e+00,  1.29246971e-26,  0.00000000e+00, ...,
#          1.32348898e-23, -6.61744490e-23,  0.00000000e+00],
#        [-3.23117427e-26, -6.46234854e-27,  0.00000000e+00, ...,
#          5.29395592e-23, -1.32348898e-22,  0.00000000e+00],
#        ...,
#        [ 2.66453526e-15, -1.33226763e-14, -1.77635684e-15, ...,
#         -2.66453526e-14,  1.77635684e-14, -1.42108547e-14],
#        [ 7.99360578e-15,  1.33226763e-14,  0.00000000e+00, ...,
#          1.77635684e-15, -7.10542736e-15, -1.06581410e-14],
#        [-1.86517468e-14,  7.10542736e-15, -1.59872116e-14, ...,
#          0.00000000e+00,  8.88178420e-15,  3.01980663e-14]])

# %%
plt.imshow(r,cmap='gray')

# %%
plt.imshow(mb_y,cmap='gray')

# %%
index = 700
# plt.plot(s[index])
plt.plot(r[index]/r[index].max())
plt.plot(mb_y[index]/mb_y[index].max())

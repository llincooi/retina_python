# %% [markdown]
# You can perform PID on MI(r;(x,v)), and compare the result of different 'x'.<br>
# 'x' can from experimental data or produce in this code for different Tau (Gramma) or cutoff frequency.<br>
# 'r' can be real responses of RGC or from NGD or from x+$\Delta$*v.<br>
# Using 20200408 Chou's data, unit2.<br>

# %% [markdown]
# # Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from matplotlib.ticker import MaxNLocator
import math
from scipy import signal
from scipy.fftpack import fft
from scipy import ndimage
from scipy.io import loadmat
from scipy.optimize import curve_fit
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import import_ipynb
try:
    os.chdir('C:\\Users\\hydro_leo\\Documents\\GitHub\\python-code\\Modules')
except:
    os.chdir('C:\\Users\\llinc\\GitHub\\python-code\\Modules')
from Spike_Generation import NL
from StimulusnResponse import expSnR
# Out:
# importing Jupyter notebook from Spike_Generation.ipynb
# importing Jupyter notebook from StimulusnResponse.ipynb

# %%
def NGD2L_TK(T, alpha, beta, gamma, g, h, l, tau_y, Amp):
    dt = np.mean(np.diff(T))
    dt = 0.1*dt
    T = np.arange(0, T[-1]+dt, dt)
    x = T/tau_y /tau_y *np.exp(-T/tau_y)*dt
    
    y=np.zeros_like(x)
    z=np.zeros_like(x)
    w=np.zeros_like(x)
    for j in range(len(x)-1):
        dy=dt*(-alpha*y[j] + x[j]-z[j] )
        dz=dt*(-beta*z[j]  + g*y[j] )
        dw=dt*(-gamma*w[j] + h*y[j]-l*z[j] )
        y[j+1]=y[j]+dy
        z[j+1]=z[j]+dz
        w[j+1]=w[j]+dw

    nTK = w[::10]/(dt) #normalized by integration
    return -Amp*nTK

# %%
#This function deals with differentiation of angle within [-pi,pi).
#It will fail if angle array x change too fast.
def angular_gradient(x):
    diffx= np.gradient(x)
    diffx[np.abs(diffx)>0.6*np.pi] -= np.pi*diffx[np.abs(diffx)>0.6*np.pi]/abs(diffx[np.abs(diffx)>0.6*np.pi])
    return diffx

# %%
figmap = [[np.nan, 7,15,23,31,39,47,np.nan],
          [     1, 8,16,24,32,40,48,    55],
          [     2, 9,17,25,33,41,49,    56],
          [     3,10,18,26,34,42,50,    57],
          [     4,11,19,27,35,43,51,    58],
          [     5,12,20,28,36,44,52,    59],
          [     6,13,21,29,37,45,53,    60],
          [np.nan,14,22,30,38,46,54,np.nan]]
figmap = np.array(figmap)
fig, ax = plt.subplots(nrows=8, ncols=8)
fig.set_size_inches(60, 30)

# %% [markdown]
# # main

# %%
filenames = ['D:\\GoogleDrive\\retina\\Chou\'s data\\20200408\\20200408_cSTA_sort_unit2']
dt = 0.01
x_list, T_list, rstate_list = expSnR(filenames, dt, 'LED', np.arange(60)+1)
x = x_list[0]
x = x-np.mean(x)
cSTA_list = [0]*60
dcn = []
for cn in range(60):
    rstate = rstate_list[0][cn,:]
    if sum(rstate) == 0: continue
    cSTA = np.correlate(x , rstate, 'same')/ np.correlate(np.ones_like(x), rstate, 'same')
    cSTA = cSTA[int(len(cSTA)/2):int(len(cSTA)/2-1/dt)-1:-1]
    taxis = -np.arange(len(cSTA))*dt
    if (np.abs(cSTA[:round(len(cSTA)/2)]) < 7*np.std(cSTA[round(len(cSTA)/2):-1])).all(): continue
    if sum(cSTA[:8]) < -1: dcn.append(cn) # exclude fitting of On-cell
    ax[np.where(figmap == cn+1)][0].plot(taxis, cSTA, 'b+:')
    cSTA_list[cn] = cSTA

# %%
name_list = ['alpha', 'beta', 'gamma', 'g', 'h', 'l', 'tau_y', 'Amp']
para_dict = {}
for l in range(len(name_list)):
    para_dict[name_list[l]] = np.zeros(60)

fit_cSTA_list = [0]*60
para_dict['error'] = np.zeros(60)
for cn in dcn.copy():
#     print(cn)
    alpha = 33. #1/sec
    beta =  2
    gamma = 46
    g = 680
    h = 14
    i = 0.3
    tau_y = 0.02
    try:
        popt,pcov = curve_fit(NGD2L_TK, np.abs(taxis), cSTA_list[cn], p0=[alpha, beta, gamma, g, h, l, tau_y, 1],
                              bounds = (0, [np.inf, np.inf, np.inf, np.inf, np.inf, np.inf, 0.1, np.inf]))
    except:
        dcn.remove(cn)
        continue
    for l in range(len(popt)):
        para_dict[name_list[l]][cn] = popt[l]
    fit_cSTA_list[cn] = NGD2L_TK(np.abs(taxis), *popt).copy()
    para_dict['error'][cn] = sum((fit_cSTA_list[cn]-cSTA_list[cn])**2)
    ax[np.where(figmap == cn+1)][0].plot(taxis, fit_cSTA_list[cn], 'r-')

# %%
for cn in range(60):
    ax[np.where(figmap == cn+1)][0].set_title(str(cn+1), fontsize = 16)
fig.set_size_inches(30, 15)
fig.tight_layout()
fig

# %%
np.save('D:\\GoogleDrive\\retina\\Chou\'s data\\20200408\\fitNGD2Lpara.npy', para_dict)

# %% [markdown]
# # examine date

# %%
Dfig, Dax = plt.subplots(nrows=8, ncols=8)
Dfig.set_size_inches(30, 15)
Dfig.tight_layout()
pcn = []
ncn = []
for cn in dcn:
    #constrani 1
    if sum(rstate_list[0][cn,:])/180 < 0.3: continue
        
    domega = 0.01
    omega = np.arange(-1,10,domega) #limited by [pi/dt,pi/dt)
    TKdw = np.sum(fit_cSTA_list[cn][np.newaxis,:]*np.exp(-1j*np.abs(taxis[np.newaxis,:])*omega[:,np.newaxis]), axis = 1)*dt
    phi = np.angle(TKdw)
    delta = -angular_gradient(phi)/domega
    Dax[np.where(figmap == cn+1)][0].set_title(str(cn+1), fontsize = 16)
        
    #constrani 2
    if delta[0] < 0: 
        pcn.append(cn)
        Dax[np.where(figmap == cn+1)][0].plot(omega[:-1], delta[:-1], 'g')
    else: 
        ncn.append(cn)
        Dax[np.where(figmap == cn+1)][0].plot(omega[:-1], delta[:-1], 'm')
        
for Daxy in Dax:
    for ax in Daxy:
        ax.axhline(0,linewidth=1, linestyle='--', c='k')
        ax.set_xlim([0,10])

# %%
# Dfig.set_size_inches(50, 25)
# Dfig.tight_layout()
# Dfig.savefig('D:\\GoogleDrive\\retina\\Chou\'s data\\20210331\\FIG\\GroupDely.tiff', bbox_inches = 'tight',pad_inches = 0.3)

# %%
data = para_dict['beta']
plt.title(r'$\beta$')
plt.hist(data[pcn],30)
plt.axvline(np.mean(data[pcn]), color = 'r')

# %%
# I1 = np.where((para_dict['beta']>10) & (para_dict['beta']<40) )[0]
# I2 = np.where((para_dict['beta']<=10) & (para_dict['beta']>0))[0]

# %%
plt.scatter(para_dict['alpha'][pcn], para_dict['beta'][pcn])
# plt.scatter(para_dict['alpha'][I1], para_dict['beta'][I1], c='r')
# plt.scatter(para_dict['alpha'][I2], para_dict['beta'][I2], c='b')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\beta$')
# Out:
# Text(0, 0.5, '$\\beta$')

# %%
plt.scatter(para_dict['alpha'][pcn], para_dict['g'][pcn])
# plt.scatter(para_dict['alpha'][I1], para_dict['Kg'][I1], c='r')
# plt.scatter(para_dict['alpha'][I2], para_dict['Kg'][I2], c='b')
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$Kg$')
# Out:
# Text(0, 0.5, '$Kg$')

# %%
plt.scatter(para_dict['beta'][pcn], para_dict['g'][pcn])
# plt.scatter(para_dict['beta'][I1], para_dict['Kg'][I1], c='r')
# plt.scatter(para_dict['beta'][I2], para_dict['Kg'][I2], c='b')
plt.xlabel(r'$\beta$')
plt.ylabel(r'$Kg$')
# Out:
# Text(0, 0.5, '$Kg$')

# %%
plt.scatter(para_dict['alpha'][pcn], para_dict['tau_y'][pcn])
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\tau_y$')
# Out:
# Text(0, 0.5, '$\\tau_y$')

# %% [markdown]
# # view parameters

# %%
import pandas as pd
data_df = pd.DataFrame(para_dict, index = np.arange(60)+1)
data_df
# Out:
#         alpha       beta        gamma            g           h         l  \
# 1    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 2    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 3    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 4    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 5    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 6    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 7   22.732794  22.938839  1952.642741   971.556999  251.254020  5.895025
# 8    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 9    0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 10   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 11   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 12   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 13   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 14  13.183782  15.481133    40.719043   810.514659  135.552063  2.575527
# 15   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 16   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 17   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 18   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 19   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 20   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 21   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 22   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 23   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 24   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 25   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 26   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 27   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 28   3.471400  21.173656  1872.801105  1038.272923  291.626013  4.555664
# 29   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 30  14.500029  16.289065    34.687191  1088.733231  147.468331  1.874560
# 31   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 32  15.791244  15.628904     7.596075  1476.334079  129.269053  1.309474
# 33   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 34   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 35   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 36   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 37   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 38   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 39  11.040152  13.611995    12.581301   914.366661   73.917634  0.996206
# 40  26.323576  14.745725  1844.721806  1331.734689  247.972881  2.007668
# 41  15.748468  15.265338  1877.025471  1068.537360  416.342804  5.914302
# 42  67.011965   9.635649    60.845306   315.613265   59.330158  1.439747
# 43   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 44   9.181580  14.930209  1749.938186  1741.933145  333.198146  0.013854
# 45  12.402713  12.377222    98.819824  1118.795871  156.383168  1.211285
# 46   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 47  13.890382  22.987187  1935.404645  1013.777755  325.094725  6.458887
# 48  14.318200  14.504987     4.221144  1487.532900  172.517019  1.709747
# 49   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 50  24.347683  16.023827  2002.813536  1908.997511  189.097214  1.102798
# 51   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 52  16.511480  16.642996  1924.282320  1377.211161  266.092706  1.443928
# 53   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 54   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 55   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 56   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 57   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 58   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
# 59  14.016362  14.463714  1868.968141  1115.389414  225.338815  1.507573
# 60   0.000000   0.000000     0.000000     0.000000    0.000000  0.000000
#
#        tau_y         Amp     error
# 1   0.000000    0.000000  0.000000
# 2   0.000000    0.000000  0.000000
# 3   0.000000    0.000000  0.000000
# 4   0.000000    0.000000  0.000000
# 5   0.000000    0.000000  0.000000
# 6   0.000000    0.000000  0.000000
# 7   0.020635   49.159057  0.413651
# 8   0.000000    0.000000  0.000000
# 9   0.000000    0.000000  0.000000
# 10  0.000000    0.000000  0.000000
# 11  0.000000    0.000000  0.000000
# 12  0.000000    0.000000  0.000000
# 13  0.000000    0.000000  0.000000
# 14  0.007782    0.965900  0.289943
# 15  0.000000    0.000000  0.000000
# 16  0.000000    0.000000  0.000000
# 17  0.000000    0.000000  0.000000
# 18  0.000000    0.000000  0.000000
# 19  0.000000    0.000000  0.000000
# 20  0.000000    0.000000  0.000000
# 21  0.000000    0.000000  0.000000
# 22  0.000000    0.000000  0.000000
# 23  0.000000    0.000000  0.000000
# 24  0.000000    0.000000  0.000000
# 25  0.000000    0.000000  0.000000
# 26  0.000000    0.000000  0.000000
# 27  0.000000    0.000000  0.000000
# 28  0.015246   21.150826  0.676898
# 29  0.000000    0.000000  0.000000
# 30  0.004663    1.002661  0.523898
# 31  0.000000    0.000000  0.000000
# 32  0.004214    0.534612  0.184475
# 33  0.000000    0.000000  0.000000
# 34  0.000000    0.000000  0.000000
# 35  0.000000    0.000000  0.000000
# 36  0.000000    0.000000  0.000000
# 37  0.000000    0.000000  0.000000
# 38  0.000000    0.000000  0.000000
# 39  0.002203    0.708349  0.128553
# 40  0.030349   40.821512  0.118685
# 41  0.018559   18.503446  0.499717
# 42  0.015929    7.433350  0.400935
# 43  0.000000    0.000000  0.000000
# 44  0.010563    4.265191  0.664750
# 45  0.009608    1.535004  0.540966
# 46  0.000000    0.000000  0.000000
# 47  0.021351   28.086079  0.296384
# 48  0.001439    0.551960  0.495295
# 49  0.000000    0.000000  0.000000
# 50  0.039661  101.248962  0.223719
# 51  0.000000    0.000000  0.000000
# 52  0.020136   23.819068  0.276589
# 53  0.000000    0.000000  0.000000
# 54  0.000000    0.000000  0.000000
# 55  0.000000    0.000000  0.000000
# 56  0.000000    0.000000  0.000000
# 57  0.000000    0.000000  0.000000
# 58  0.000000    0.000000  0.000000
# 59  0.016421   27.089309  0.481144
# 60  0.000000    0.000000  0.000000

# %%
# a = np.load('D:\\GoogleDrive\\retina\\Chou\'s data\\20200408\\fitNGDpara.npy', allow_pickle=True)[()]
